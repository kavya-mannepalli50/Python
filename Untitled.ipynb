# %%
import pandas as pd

df = pd.read_csv("/content/Customer Purchase.csv")
df.head()
# Out:
#    Customer ID  Age  Gender Education   Review Purchased
# 0         1021   30  Female    School  Average        No
# 1         1022   68  Female        UG     Poor        No
# 2         1023   70  Female        PG     Good        No
# 3         1024   72  Female        PG     Good        No
# 4         1025   16  Female        UG  Average        No

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})

# %%
df['Purchased'] = df['Purchased'].map({'Yes': 1, 'No': 0})

# %%
df['Purchased'] = df['Purchased'].map({'Yes': 1, 'No': 0})

# %%
df.isnull().sum()
# Out:
# Customer ID     0
# Age             0
# Gender          0
# Education       0
# Review          0
# Purchased      50
# dtype: int64

# %%
df.describe()
# Out:
#        Customer ID        Age     Gender  Purchased
# count     50.00000  50.000000  50.000000        0.0
# mean    1045.50000  54.160000   0.420000        NaN
# std       14.57738  25.658161   0.498569        NaN
# min     1021.00000  15.000000   0.000000        NaN
# 25%     1033.25000  30.250000   0.000000        NaN
# 50%     1045.50000  57.000000   0.000000        NaN
# 75%     1057.75000  74.000000   1.000000        NaN
# max     1070.00000  98.000000   1.000000        NaN

# %%
import matplotlib.pyplot as plt

plt.hist(df['Age'], bins=10)
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram of Age")
plt.show()

# %%
plt.scatter(df['Age'], df['Gender'], c=df['Purchased'])
plt.xlabel("Age")
plt.ylabel("Gender (0 = Female, 1 = Male)")
plt.title("Age vs Gender by Purchase")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df[['Age', 'Gender']]
y = df['Purchased']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
import pandas as pd
from io import StringIO

data = """Customer ID,Age,Gender,Education,Review,Purchased
1021,30,Female,School,Average,No
1022,68,Female,UG,Poor,No
1023,70,Female,PG,Good,No
1024,72,Female,PG,Good,No
1025,16,Female,UG,Average,No
1026,31,Female,School,Average,Yes
1027,18,Male,School,Good,No
1028,60,Female,School,Poor,Yes
1029,65,Female,UG,Average,No
1030,74,Male,UG,Good,Yes
1031,98,Female,UG,Good,Yes
1032,74,Male,UG,Good,Yes
1033,51,Male,School,Poor,No
1034,57,Female,School,Average,No
1035,15,Male,PG,Poor,Yes
1036,75,Male,UG,Poor,No
1037,59,Male,UG,Poor,Yes
1038,22,Female,UG,Poor,Yes
1039,19,Male,School,Good,No
1040,97,Male,PG,Poor,Yes
1041,57,Female,School,Average,Yes
1042,32,Male,PG,Average,No
1043,18,Female,PG,Poor,Yes
1044,96,Female,School,Good,No
1045,16,Female,PG,Average,Yes
1046,57,Female,School,Good,No
1047,53,Female,PG,Poor,No
1048,69,Female,PG,Poor,No
1049,48,Male,School,Poor,No
1050,83,Female,UG,Average,Yes
1051,73,Male,UG,Average,No
1052,22,Female,School,Poor,Yes
1053,92,Male,UG,Average,Yes
1054,89,Female,PG,Good,Yes
1055,86,Male,School,Average,No
1056,74,Male,School,Poor,Yes
1057,34,Female,UG,Good,Yes
1058,94,Male,PG,Average,Yes
1059,45,Female,School,Good,No
1060,76,Male,PG,Poor,No
1061,39,Male,School,Good,No
1062,23,Male,PG,Good,Yes
1063,30,Female,PG,Good,Yes
1064,27,Male,PG,Poor,No
1065,77,Female,UG,Average,No
1066,61,Male,PG,Poor,Yes
1067,64,Female,PG,Poor,No
1068,38,Female,PG,Good,Yes
1069,39,Female,UG,Good,Yes
1070,25,Female,UG,Good,No
"""

df = pd.read_csv(StringIO(data))

# %%
# Encode Gender
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})

# Encode Education
df['Education'] = df['Education'].map({'School': 0, 'UG': 1, 'PG': 2})

# Encode Review
df['Review'] = df['Review'].map({'Poor': 0, 'Average': 1, 'Good': 2})

# Encode Purchased (Target)
df['Purchased'] = df['Purchased'].map({'Yes': 1, 'No': 0})

# %%
from sklearn.model_selection import train_test_split

X = df[['Age', 'Gender', 'Education', 'Review']]
y = df['Purchased']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5333333333333333
#
# Confusion Matrix:
#  [[4 5]
#  [2 4]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.44      0.53         9
#            1       0.44      0.67      0.53         6
#
#     accuracy                           0.53        15
#    macro avg       0.56      0.56      0.53        15
# weighted avg       0.58      0.53      0.53        15
